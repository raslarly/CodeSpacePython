# %%
"""
    Problem tanimi: CIFAR10 veriseti siniflandirma problemi
    CNN kullanilacak
"""
import torch # pytorch
import torch.nn as nn # sinir agi katmanlari icin
import torch.optim as optim # optimizsayon algoritmasi icin
import torchvision # goruntu isleme icin
import torcvision.transforms as transforms 
import matplotlib.pyplot as plt
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /usr/lib/python3.12/importlib/metadata/__init__.py in read_text(self, filename)
#     818         ):
# --> 819             return self._path.joinpath(filename).read_text(encoding='utf-8')
#     820
#
# /usr/lib/python3.12/pathlib.py in read_text(self, encoding, errors)
#    1026         encoding = io.text_encoding(encoding)
# -> 1027         with self.open(mode='r', encoding=encoding, errors=errors) as f:
#    1028             return f.read()
#
# /usr/lib/python3.12/pathlib.py in open(self, mode, buffering, encoding, errors, newline)
#    1012             encoding = io.text_encoding(encoding)
# -> 1013         return io.open(self, mode, buffering, encoding, errors, newline)
#    1014
#
# FileNotFoundError: [Errno 2] No such file or directory: '/usr/local/lib/python3.12/dist-packages/referencing-0.37.0.dist-info/entry_points.txt'
# ...

# %%
def get_data_loader(batch_size=64):
    transform = transforms.Compose([
        # goruntuyu tensore cevir
        transforms.toTensor(),
        # renkli bir goruntu oldugundan 3 adet 0.5 kullanilmistir . 
        # RGB kanallarini normalize et
        transforms.Normalize((0.5,0.5,0.5),(0.5,0.5,0.5))        
        ])
   # CIFAR10 veri setini indir ve egitim test veri setini olustur
   
   train_set = torchvision.datasets.CIFAR10(root ='./data',
                                            train =True,
                                            download=True,
                                            transform=transform)
    test_set = torchvision.datasets.CIFAR10(root='./data',
                                            train = False,
